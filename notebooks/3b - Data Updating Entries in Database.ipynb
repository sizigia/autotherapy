# %% [markdown]
# # Imports

# %%
import io
import json
import os
import pickle
import re
import string
from collections import defaultdict
from datetime import datetime
from pprint import pprint

import cv2
import emoji
import numpy as np
import pandas as pd
import pymongo
import pytesseract
from dotenv import load_dotenv
from google.cloud import vision
from google.oauth2 import service_account
from pytesseract import Output

from helpers import (account_info, connect_to_db, extract_from_json,
                     extract_hashtags, extract_text, extract_text_from_image)

# %% [markdown]
# # Connection to DB

# %%
project_folder = os.path.expanduser('../../')
load_dotenv(os.path.join(project_folder, '.env'))


# Google Vision API
GOOGLE_APPLICATION_CREDENTIALS = os.getenv("GOOGLE_APPLICATION_CREDENTIALS")
credentials = service_account.Credentials.from_service_account_file(project_folder + GOOGLE_APPLICATION_CREDENTIALS)
client_options = {'api_endpoint': 'eu-vision.googleapis.com'}
google_client = vision.ImageAnnotatorClient(client_options=client_options, credentials=credentials)

# MongoDB
client = connect_to_db()
db = client.accounts # connect to my database
posts = db['posts'] # collection of posts
authors = db['authors'] # collection of authors

# %% [raw]
# query = {'account': 'mindfulmft'}
#
# for row in authors.find(query):
#     print(pprint(row))

# %% [markdown]
# ### Load to pandas

# %%
cursor = posts.find()
entries = list(cursor)

df = pd.DataFrame(entries)
df.head()
# Out:
#                         _id     account     post_id  likes  comments  \
# 0  5f34706c8091264adc7b3c0f  mindfulmft  ierq6xRnBL     55         1
# 1  5f34706d8091264adc7b3c11  mindfulmft  ietVO_RnD_     33         0
# 2  5f34706d8091264adc7b3c12  mindfulmft  ietrkpRnEl     65         1
# 3  5f34706d8091264adc7b3c13  mindfulmft  ieum0hxnF-     39         1
# 4  5f34706d8091264adc7b3c14  mindfulmft  jH1aVfxnDG     61         1
#
#                  date                                            content  \
# 0 2013-12-28 15:53:14  #therapy #positivequotes #quotes #marriage #re...
# 1 2013-12-28 16:07:45  #motivation #love #power #encourage #journey #...
# 2 2013-12-28 16:10:48  #storms #accomplishments #roots #strength #liv...
# 3 2013-12-28 16:18:53  #words #self #life #MINDFULMFT #mindfulness #c...
# 4 2014-01-13 15:27:13  #truth #wisdom #wise #think #act #motivation #...
#
#                                             hashtags  number_hashtags  \
# 0  guidance challenge mentalhealth quotes positiv...               14
# 1  journey power forward relationship encourage a...               14
# 2  storms wisdom forward relationship encourageme...               15
# 3  wisdom control encouragement lessons motivatio...               13
# 4  think wisdom wise family counseling encourage ...               16
#
#                                             img_text  number_emojis mentions  \
# 0                  true humility is staying teachabl            0.0
# 1  YOU ARE FAR Coo. pnart- TO BE THE ONLY THING S...            0.0
# 2  Storms make trees take deeper root ss - Dolly ...            0.0
# 3  - Let anyone determine your self-worth. = Spea...            0.0
# 4  Most of the problems in life are because of tw...            0.0
#
#   emoji_terms pre_cleaned_text url_email
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ```python
# for folder in accounts: # folder == username
#     query = {'account': account}
#     for row in authors.find(query):
#         print(pprint(row))
# ```

# %% [raw]
# raw_docs_path = '../data/scraped_accounts/'
# accounts = [dir_ for dir_ in os.listdir(raw_docs_path) if (os.path.isdir(raw_docs_path + dir_))]
#
# for folder in accounts[1:]: # folder == username
#     basedir = f"{raw_docs_path}{folder}/"
#     print(basedir)
#     print(folder.upper())
#
#     txt_ = [i for i in os.listdir(basedir) if (i.startswith('20') and i.endswith('.txt'))]
#     images_ = [i for i in os.listdir(basedir) if (i.startswith('20') and i.endswith('.jpg'))]
#
#     for idx, file_ in enumerate(txt_):
#         distinct_file_path = re.search('(.+UTC)', file_).group(0)
#         filepath = f"{basedir}{distinct_file_path}"
#
#         print('Processing {} of {}: {}'.format(idx, len(txt_), distinct_file_path))
#
#         # Build entry
#         post = extract_from_json(filepath + '.json')
#         post['content'] = extract_text(filepath + '.txt')
#         post['hashtags'], post['number_hashtags'] = extract_hashtags(post['content'])
#
#         if not os.path.isfile(filepath + '.jpg'):
#             doc = ''
#             for im in [i for i in images_ if (distinct_file_path in i)]:
#                 doc += extract_text_from_image(f"{basedir}{im}") + ' '
#
#             post['img_text'] = doc
#         else:
#             post['img_text'] = extract_text_from_image(filepath + '.jpg')
#
#
#
#         if not posts.count_documents({'post_id': post['post_id']}):
#             posts.insert_one(post)
#         else:
#             posts.update_one(
#                 {'post_id': post['post_id']},
#                 {'$set': {
#                     'likes': post['likes'],
#                     'comments': post['comments'],
#                     'content': post['content'],
#                     'img_text': post['img_text'],
#                     'hashtags': post['hashtags'],
#                     'number_hashtags': post['number_hashtags']}
#                 })
#
#
#         author = account_info(filepath + '.json')
#         if not authors.count_documents({'account': author['account']}):
#             authors.insert_one(author)

# %% [markdown]
# # GOOGLE VISION API

# %% [raw]
# minaa_b_handwritten = set(pickle.load(open('uri_for_apirequests.pkl', 'rb')))

# %% [raw]
# raw_docs_path = '../data/scraped_accounts/'
# folder = 'minaa_b'
# basedir = f"{raw_docs_path}{folder}/"
#
# print(basedir)
# print(folder.upper())
#
# txt_ = [i for i in os.listdir(basedir) if (i.startswith('20') and i.endswith('.txt') and (i[:-4] in minaa_b_handwritten))]
# images_ = [i for i in os.listdir(basedir) if (i.startswith('20') and i.endswith('.jpg') and (i[:-4] in minaa_b_handwritten))]
#
# for idx, file_ in enumerate(txt_):
#     distinct_file_path = re.search('(.+UTC)', file_).group(0)
#     filepath = f"{basedir}{distinct_file_path}"
#
#     print('Processing {} of {}: {}'.format(idx, len(txt_), distinct_file_path))
#
#     # Build entry
#     post = extract_from_json(filepath + '.json')
#     post['content'] = extract_text(filepath + '.txt')
#     post['hashtags'], post['number_hashtags'] = extract_hashtags(post['content'])
#
#
#     with open(filepath + '.jpg', 'rb') as image_file:
#         content = image_file.read()
#
#     image_to_request = vision.types.Image(content=content)
#     response = google_client.text_detection(image=image_to_request)
#     texts = response.text_annotations
#     post['img_text'] = texts[0].description
#
#
#
#     posts.update_one(
#         {'post_id': post['post_id']},
#         {'$set': {
#             'likes': post['likes'],
#             'comments': post['comments'],
#             'content': post['content'],
#             'img_text': post['img_text'],
#             'hashtags': post['hashtags'],
#             'number_hashtags': post['number_hashtags']}
#         })

# %% [raw]
# for file_ in minaa_b_handwritten:
#     path = filepath + '.jpg'
#
#     with io.open(path, 'rb') as image_file:
#         content = image_file.read()
#
#     image = vision.types.Image(content=content)
#     response = client.text_detection(image=image)
#     texts = response.text_annotations
#     post['img_text'] = texts[0].description
#
# posts.update_one(
#             {'post_id': post['post_id']},
#             {'$set': {
#                 'likes': post['likes'],
#                 'comments': post['comments'],
#                 'content': post['content'],
#                 'img_text': post['img_text'],
#                 'hashtags': post['hashtags'],
#                 'number_hashtags': post['number_hashtags']}
#             })

# %% [markdown]
# # Fix entries with missing text

# %%
df.img_text.isna().sum()
# Out:
# 27

# %%
missing_img_text = df[df.img_text.isna()]
missing_img_text
# Out:
#                            _id        account      post_id  likes  comments  \
# 152   5f3470858091264adc7b3ca8     mindfulmft   mAipZuxnGT    210         7
# 237   5f3470928091264adc7b3cfd     mindfulmft   oqa0JUxnBH    349        15
# 243   5f3470938091264adc7b3d03     mindfulmft   o5-DqDxnPm    443        42
# 323   5f34709e8091264adc7b3d53     mindfulmft   sNKuUXRnG4    644        27
# 1755  5f34717d8091264adc7b42ec        minaa_b  BNFLBMgghX4    161        10
# 1785  5f3471828091264adc7b430a        minaa_b  BNmqLA-gBv3    167         7
# 1834  5f3471898091264adc7b433b        minaa_b  BOfzKoxATmT    297         8
# 2012  5f3471a68091264adc7b43ed        minaa_b  BR0sByPDtyX    200         2
# 2459  5f3471ec8091264adc7b45ad    nedratawwab  BaRpSzgg_6E     18         1
# 3045  5f3472478091264adc7b47f7        minaa_b  BgjBXM6APou    547        16
# 3128  5f3472568091264adc7b484a    nedratawwab  BheeRjgAaJB     39         1
# 3296  5f34726f8091264adc7b48f3    nedratawwab  BjZjCt8AlrA     24        14
# 3304  5f3472708091264adc7b48fb        minaa_b  BjciRdLHtBL    538         7
# 4313  5f3473148091264adc7b4cef        minaa_b  BrsdoZzl56L   1040        25
# 5227  5f3473a68091264adc7b5081  seerutkchawla  Bx3TALCnz2g     22         3
# 5262  5f3473ac8091264adc7b50a5  seerutkchawla  ByFWX4DAUb7     41         7
# 5278  5f3473ae8091264adc7b50b5  seerutkchawla  ByH6IpGg2EH     38         1
# 5290  5f3473b08091264adc7b50c1  seerutkchawla  ByK5D3Dgkx9     40         2
# 5298  5f3473b18091264adc7b50c9  seerutkchawla  ByLVkt_AYxi     76         3
# 5309  5f3473b38091264adc7b50d4  seerutkchawla  ByPsGEzA9KG     47         1
# 5323  5f3473b68091264adc7b50e2  seerutkchawla  BySN5u7ghpz     22         4
# 5335  5f3473ba8091264adc7b50ee  seerutkchawla  ByVpczsgM8J     35         1
# 5716  5f3473f98091264adc7b526b  seerutkchawla  B0jMcawgCM2    216        75
# 6137  5f34743d8091264adc7b5410     mindfulmft  B26-EjYFCqr   1589        57
# 8555  5f347c6d8091264adc7b5d82    risingwoman  B9Z-6FkBRSN  39008       471
# 8556  5f347ca58091264adc7b5d83  seerutkchawla  B_5vVeuDl4e   3001       552
# 8557  5f347cc38091264adc7b5d84    risingwoman  CBlzVOnnGqj   3674       112
#
#                     date                                            content  \
# 152  2014-03-26 10:02:45  Time\n\nSs\nnothing\nunless\n\nyou move\n\nwit\n
#
# 237  2014-05-31 09:25:12  YOUR LARGEST\nFEAR CARRIES\n\nYOUR GREATEST\nG...
# 243  2014-06-06 10:21:46  The best kind of people are\nthe ones that com...
# 323  2014-08-27 10:52:12  “And suddenly\nyou know... It’s\ntime to start...
# 1755 2016-11-21 12:36:51                                                \n
#
# 1785 2016-12-04 12:44:01  darling,\n\nyou were created\nmagnificently.\n...
# 1834 2016-12-26 17:19:19  do what's hard.\n\ndo what's unexpected.\n\ndo...
# 2012 2017-03-19 10:35:10
#
# 2459 2017-10-15 12:40:25                                                \n
#
# 3045 2018-03-20 09:46:11  GIVE YovRselh peRmission To FEEL.\nort pont iv...
# 3128 2018-04-12 11:54:00  Yon G\n\n1 We can't eliminate\n4 stress. But, ...
# 3296 2018-05-30 07:02:16       \n\nSn ©» ©\n@kaleidoscopecounseling\n\n \n
#
# 3304 2018-05-31 10:53:15  AND €veN IF 1 WAS STRUGGLING\n\nYESTERPAY: 1AM...
# 4313 2018-12-22 10:31:42  _ Minaa B.\n@MinaaBe\n\nHealing:\n\nIt is a re...
# 5227 2019-05-24 19:38:50                                                \n
#
# 5262 2019-05-30 06:39:33                                                \n
#
# 5278 2019-05-31 06:29:35                                                \n
#
# 5290 2019-06-01 10:22:09                          Go the\nf*ck to sleep!\n
#
# 5298 2019-06-01 14:26:07  IT’S NOT ALL IN YOUR HEAD:\n\nIT’S ALSO IN YOU...
# 5309 2019-06-03 07:01:50                 GUT\n\nWILL\nFUCK\n\nVEOnE= Cee\n
#
# 5323 2019-06-04 06:36:02  e\n\n,ROWTEI\nnindse\n‘AN HELI\n\nOur menta\n\...
# 5335 2019-06-05 14:32:47  reminders for\n\nYOUR WORST DAYS...\n\n \n\nIn...
# 5716 2019-07-30 13:53:42                                                \n
#
# 6137 2019-09-27 12:31:53                                                \n
#
# 8555 2020-03-06 15:42:00  I hope you know that no matter what\nyou've be...
# 8556 2020-05-07 17:44:25  Raising ethical, factual, and safeguarding\nco...
# 8557 2020-06-18 16:58:33                                                \n
#
#
#      hashtags  number_hashtags img_text  number_emojis  \
# 152                          0      NaN            0.0
# 237                          0      NaN            0.0
# 243                          0      NaN            0.0
# 323                          0      NaN            0.0
# 1755                         0      NaN            0.0
# 1785                         0      NaN            0.0
# 1834                         0      NaN            0.0
# 2012                         0      NaN            0.0
# 2459                         0      NaN            0.0
# 3045                         0      NaN            0.0
# 3128                         0      NaN            0.0
# 3296                         0      NaN            2.0
# 3304                         0      NaN            0.0
# 4313                         0      NaN            0.0
# 5227                         0      NaN            0.0
# 5262                         0      NaN            0.0
# 5278                         0      NaN            0.0
# 5290                         0      NaN            0.0
# 5298                         0      NaN            0.0
# 5309                         0      NaN            0.0
# 5323                         0      NaN            0.0
# 5335                         0      NaN            0.0
# 5716                         0      NaN            0.0
# 6137                         0      NaN            0.0
# 8555                         0      NaN            0.0
# 8556                         0      NaN            0.0
# 8557                         0      NaN            0.0
#
#                     mentions emoji_terms  \
# 152
# 237
# 243
# 323
# 1755
# 1785
# 1834
# 2012
# 2459
# 3045
# 3128
# 3296  kaleidoscopecounseling   copyright
# 3304
# 4313                 minaabe
# 5227
# 5262
# 5278
# 5290
# 5298           seerutkchawla
# 5309
# 5323           hawd seérutkh
# 5335
# 5716
# 6137
# 8555
# 8556           seerutkchawla
# 8557
#
#                                        pre_cleaned_text url_email
# 152                 Time Ss nothing unless you move wit
# 237     YOUR LARGEST FEAR CARRIES YOUR GREATEST GROWTH.
# 243   The best kind of people are the ones that come...
# 323   And suddenly you know It is time to start some...
# 1755
# 1785  darling, you were created magnificently. flee ...
# 1834  do what is hard. do what is unexpected. do wha...
# 2012
# 2459
# 3045  GIVE YovRselh peRmission To FEEL. ort pont ive...
# 3128  Yon G 1 We can not eliminate 4 stress. But, we...
# 3296                                                 Sn
# 3304  AND veN IF 1 WAS STRUGGLING YESTERPAY: 1AM NEW...
# 4313  Minaa B. Healing: It is a requirement. You wer...
# 5227
# 5262
# 5278
# 5290                              Go the f ck to sleep!
# 5298  IT'S NOT ALL IN YOUR HEAD: IT'S ALSO IN YOUR M...
# 5309                            GUT WILL FUCK VEOnE Cee
# 5323        e ,ROWTEI nindse AN HELI Our menta LEALT SE
# 5335               reminders for YOUR WORST DAYS InShOE
# 5716
# 6137
# 8555  I hope you know that no matter what you have b...
# 8556  Raising ethical, factual, and safeguarding con...
# 8557

# %% [raw]
# entries_to_update = missing_img_text[['_id', 'account', 'post_id', 'date', 'img_text']].to_dict(orient='records')
#
# basedir = '../data/scraped_accounts/'
#
# for post in entries_to_update:
#     acc_folder = post['account']
#     distinct_file_path = post['date'].strftime(format='%Y-%m-%d_') #.tz_localize('UTC')
#
#     files_to_check = [f for f in os.listdir(basedir + acc_folder) if (f.endswith('.jpg') and f.startswith(distinct_file_path))]
#
#     s = []
#     for img in files_to_check:
#         imgtext = extract_text_from_image(f"{basedir}{acc_folder}/{img}")
#         s.append(imgtext)
#
#     post['img_text'] = ' '.join(s)

# %%
entries_to_update

# %% [raw]
# for post in entries_to_update[:-1]:
#     acc_folder = post['account']
#     distinct_file_path = post['date'].strftime(format='%Y-%m-%d_') #.tz_localize('UTC')
#
#     jsonfile = [f for f in os.listdir(basedir + acc_folder) if (f.endswith('.json') and f.startswith(distinct_file_path))][0]
#
#     print(pprint(json.load(open(f"{basedir}{acc_folder}/{jsonfile}", 'rb'))))

# %%
entries_to_delete = missing_img_text[['_id']].to_dict(orient='records')

# %%
ids = [obj_id['_id'] for obj_id in entries_to_delete]
ids
# Out:
# [ObjectId('5f3470858091264adc7b3ca8'),
#  ObjectId('5f3470928091264adc7b3cfd'),
#  ObjectId('5f3470938091264adc7b3d03'),
#  ObjectId('5f34709e8091264adc7b3d53'),
#  ObjectId('5f34717d8091264adc7b42ec'),
#  ObjectId('5f3471828091264adc7b430a'),
#  ObjectId('5f3471898091264adc7b433b'),
#  ObjectId('5f3471a68091264adc7b43ed'),
#  ObjectId('5f3471ec8091264adc7b45ad'),
#  ObjectId('5f3472478091264adc7b47f7'),
#  ObjectId('5f3472568091264adc7b484a'),
#  ObjectId('5f34726f8091264adc7b48f3'),
#  ObjectId('5f3472708091264adc7b48fb'),
#  ObjectId('5f3473148091264adc7b4cef'),
#  ObjectId('5f3473a68091264adc7b5081'),
#  ObjectId('5f3473ac8091264adc7b50a5'),
#  ObjectId('5f3473ae8091264adc7b50b5'),
#  ObjectId('5f3473b08091264adc7b50c1'),
#  ObjectId('5f3473b18091264adc7b50c9'),
#  ObjectId('5f3473b38091264adc7b50d4'),
#  ObjectId('5f3473b68091264adc7b50e2'),
#  ObjectId('5f3473ba8091264adc7b50ee'),
#  ObjectId('5f3473f98091264adc7b526b'),
#  ObjectId('5f34743d8091264adc7b5410'),
#  ObjectId('5f347c6d8091264adc7b5d82'),
#  ObjectId('5f347ca58091264adc7b5d83'),
#  ObjectId('5f347cc38091264adc7b5d84')]

# %%
type(ids[0])
# Out:
# bson.objectid.ObjectId

# %%
result = posts.delete_many({'_id': {'$in': ids}})

# %%
result

# %%
cursor = posts.find()
entries = list(cursor)

df = pd.DataFrame(entries)
df.head()
# Out:
#                         _id     account     post_id  likes  comments  \
# 0  5f34706c8091264adc7b3c0f  mindfulmft  ierq6xRnBL     55         1
# 1  5f34706d8091264adc7b3c11  mindfulmft  ietVO_RnD_     33         0
# 2  5f34706d8091264adc7b3c12  mindfulmft  ietrkpRnEl     65         1
# 3  5f34706d8091264adc7b3c13  mindfulmft  ieum0hxnF-     39         1
# 4  5f34706d8091264adc7b3c14  mindfulmft  jH1aVfxnDG     61         1
#
#                  date                                            content  \
# 0 2013-12-28 15:53:14  #therapy #positivequotes #quotes #marriage #re...
# 1 2013-12-28 16:07:45  #motivation #love #power #encourage #journey #...
# 2 2013-12-28 16:10:48  #storms #accomplishments #roots #strength #liv...
# 3 2013-12-28 16:18:53  #words #self #life #MINDFULMFT #mindfulness #c...
# 4 2014-01-13 15:27:13  #truth #wisdom #wise #think #act #motivation #...
#
#                                             hashtags  number_hashtags  \
# 0  guidance challenge mentalhealth quotes positiv...               14
# 1  journey power forward relationship encourage a...               14
# 2  storms wisdom forward relationship encourageme...               15
# 3  wisdom control encouragement lessons motivatio...               13
# 4  think wisdom wise family counseling encourage ...               16
#
#                                             img_text  number_emojis mentions  \
# 0                  true humility is staying teachabl            0.0
# 1  YOU ARE FAR Coo. pnart- TO BE THE ONLY THING S...            0.0
# 2  Storms make trees take deeper root ss - Dolly ...            0.0
# 3  - Let anyone determine your self-worth. = Spea...            0.0
# 4  Most of the problems in life are because of tw...            0.0
#
#   emoji_terms pre_cleaned_text url_email
# 0
# 1
# 2
# 3
# 4

# %%
df[df.img_text.isna()]
# Out:
# Empty DataFrame
# Columns: [_id, account, post_id, likes, comments, date, content, hashtags, number_hashtags, img_text, number_emojis, mentions, emoji_terms, pre_cleaned_text, url_email]
# Index: []
